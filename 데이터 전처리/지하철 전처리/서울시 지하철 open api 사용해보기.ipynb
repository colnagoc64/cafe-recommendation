# %%
import requests
import json
import pandas as pd

# %%
url="http://openapi.seoul.go.kr:8088/5a5a7845746768633130314163495342/json/CardSubwayTime/1/1000/202101/"

# %%
resp=requests.get(url)
print(resp.status_code)
print(resp.text)
# Out:
# 200
# ...

# %%
data=resp.json()

# %%
print(data)
# Out:
# {'CardSubwayTime': {'list_total_count': 604, 'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'}, 'row': [{'USE_MON': '202101', 'LINE_NUM': '1호선', 'SUB_STA_NM': '서울역', 'FOUR_RIDE_NUM': 445.0, 'FOUR_ALIGHT_NUM': 8.0, 'FIVE_RIDE_NUM': 6832.0, 'FIVE_ALIGHT_NUM': 4781.0, 'SIX_RIDE_NUM': 8835.0, 'SIX_ALIGHT_NUM': 24937.0, 'SEVEN_RIDE_NUM': 27116.0, 'SEVEN_ALIGHT_NUM': 66431.0, 'EIGHT_RIDE_NUM': 43277.0, 'EIGHT_ALIGHT_NUM': 145325.0, 'NINE_RIDE_NUM': 31927.0, 'NINE_ALIGHT_NUM': 91672.0, 'TEN_RIDE_NUM': 29589.0, 'TEN_ALIGHT_NUM': 44874.0, 'ELEVEN_RIDE_NUM': 35644.0, 'ELEVEN_ALIGHT_NUM': 36552.0, 'TWELVE_RIDE_NUM': 43336.0, 'TWELVE_ALIGHT_NUM': 38972.0, 'THIRTEEN_RIDE_NUM': 44588.0, 'THIRTEEN_ALIGHT_NUM': 39053.0, 'FOURTEEN_RIDE_NUM': 40502.0, 'FOURTEEN_ALIGHT_NUM': 37105.0, 'FIFTEEN_RIDE_NUM': 50240.0, 'FIFTEEN_ALIGHT_NUM': 38482.0, 'SIXTEEN_RIDE_NUM': 58078.0, 'SIXTEEN_ALIGHT_NUM': 39890.0, 'SEVENTEEN_RIDE_NUM': 93883.0, 'SEVENTEEN_ALIGHT_NUM': 45769.0, 'EIGHTEEN_RIDE_NUM': 144127.0, '
# ...

# %%
subway=pd.DataFrame(data)
subway
# Out:
#                                                      CardSubwayTime
# RESULT                {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'}
# list_total_count                                                604
# row               [{'USE_MON': '202101', 'LINE_NUM': '1호선', 'SUB...

# %%
subway.to_csv('subway.csv')
